# %% [markdown]
# ##### ❇️ Pandas 🐼 Styling

# %%
import pandas as pd

# %%
df = pd.read_csv('stocks2.csv').sample(frac = 0.5)

# %%
# highlighting min, max and NaN values
df.style.highlight_min(color='green').highlight_max(color = 'magenta').highlight_null()
# Out:
# <style type="text/css">
# #T_65ee9_row0_col1, #T_65ee9_row0_col2, #T_65ee9_row0_col3, #T_65ee9_row0_col4, #T_65ee9_row1_col5, #T_65ee9_row5_col0 {
#   background-color: green;
# }
# #T_65ee9_row1_col1, #T_65ee9_row1_col2, #T_65ee9_row1_col3, #T_65ee9_row1_col4, #T_65ee9_row2_col5, #T_65ee9_row4_col0 {
#   background-color: magenta;
# }
# #T_65ee9_row2_col4, #T_65ee9_row5_col2 {
#   background-color: red;
# }
# </style>
# <table id="T_65ee9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_65ee9_level0_col0" class="col_heading level0 col0" >date</th>
#       <th id="T_65ee9_level0_col1" class="col_heading level0 col1" >open</th>
#       <th id="T_65ee9_level0_col2" class="col_heading level0 col2" >high</th>
#       <th id="T_65ee9_level0_col3" class="col_heading level0 col3" >low</th>
#       <th id="T_65ee9_level0_col4" class="col_heading level0 col4" >close</th>
#       <th id="T_65ee9_level0_col5" class="col_heading level0 col5" >volume</th>
# ...

# %%
#Color the background in a gradient style.
df.style.background_gradient()
# Out:
# <style type="text/css">
# #T_de326_row0_col1, #T_de326_row0_col2, #T_de326_row0_col3, #T_de326_row0_col4, #T_de326_row1_col5 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_de326_row0_col5 {
#   background-color: #9ab8d8;
#   color: #000000;
# }
# #T_de326_row1_col1, #T_de326_row1_col2, #T_de326_row1_col3, #T_de326_row1_col4, #T_de326_row2_col5 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_de326_row2_col1 {
#   background-color: #0872b1;
#   color: #f1f1f1;
# }
# #T_de326_row2_col2 {
#   background-color: #0c74b2;
#   color: #f1f1f1;
# }
# #T_de326_row2_col3 {
#   background-color: #1278b4;
#   color: #f1f1f1;
# }
# #T_de326_row2_col4, #T_de326_row5_col2 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_de326_row3_col1 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_de326_row3_col2 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_de326_row3_col3 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# ...

# %%
# Making table borders blue with text color as green.
df.style.set_properties(**{'border': '1.3px solid blue',
                          'color': 'green'})
# Out:
# <style type="text/css">
# #T_a96db_row0_col0, #T_a96db_row0_col1, #T_a96db_row0_col2, #T_a96db_row0_col3, #T_a96db_row0_col4, #T_a96db_row0_col5, #T_a96db_row1_col0, #T_a96db_row1_col1, #T_a96db_row1_col2, #T_a96db_row1_col3, #T_a96db_row1_col4, #T_a96db_row1_col5, #T_a96db_row2_col0, #T_a96db_row2_col1, #T_a96db_row2_col2, #T_a96db_row2_col3, #T_a96db_row2_col4, #T_a96db_row2_col5, #T_a96db_row3_col0, #T_a96db_row3_col1, #T_a96db_row3_col2, #T_a96db_row3_col3, #T_a96db_row3_col4, #T_a96db_row3_col5, #T_a96db_row4_col0, #T_a96db_row4_col1, #T_a96db_row4_col2, #T_a96db_row4_col3, #T_a96db_row4_col4, #T_a96db_row4_col5, #T_a96db_row5_col0, #T_a96db_row5_col1, #T_a96db_row5_col2, #T_a96db_row5_col3, #T_a96db_row5_col4, #T_a96db_row5_col5 {
#   border: 1.3px solid blue;
#   color: green;
# }
# </style>
# <table id="T_a96db">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a96db_level0_col0" class="col_heading level0 col0" >date</th>
# ...
