# %% [markdown]
# ##### ❇️ Matplotlib: Pie Chart

# %%
import matplotlib.pyplot as plt

# The slices are ordered and plotted counter-clockwise:
labels = 'Python', 'Java', 'C++', 'C#', 'JavaScript', 'PHP'
sizes = [24.8, 31.3, 9.4, 10.8, 11.3, 12.4]

# only "explode" the 1st slice (i.e. 'Python')
explode = (0.1, 0, 0, 0, 0, 0.0)  

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)



plt.show()

# %% [markdown]
# ##### ❇️ Hope you enjoyed reading!! 📖
# ##### ❇️ follow → @akshay_pachaar
