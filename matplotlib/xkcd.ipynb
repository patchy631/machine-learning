# %% [markdown]
# #### Matplotlib `Comic` Plots! 🚀

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.xkcd()
plt.plot(np.sin(np.linspace(0, 10)))
plt.title('Hurray!')
# Out:
# Text(0.5, 1.0, 'Hurray!')
