# %% [markdown]
# ##### ❇️ Mirror an Image in Python 🐍

# %%
from PIL import Image
import numpy as np

# %%
img = Image.open('DALLE_2_car.png')
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=200x200 at 0x7FB63E502F10>

# %%
arr = np.array(img)
mirror_img = Image.fromarray(arr[:,::-1,:])
mirror_img
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7FB63E565A30>

# %% [markdown]
# ##### ❇️ Now try inverting it using similar logic ✅
# ##### ❇️ Hope you enjoyed reading!! 📖
# ##### ❇️ follow → @akshay_pachaar
