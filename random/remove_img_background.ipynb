# %% [markdown]
# ## ❇️ Remove Image Background using `Python 🐍`

# %%
from PIL import Image
import rembg

# %%
img = Image.open('messi_vs_nld.png')
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=446x293>

# %%
img_bg_removed = rembg.remove(img)
img_bg_removed
# Out:
# <PIL.Image.Image image mode=RGBA size=446x293>

# %% [markdown]
# ##### ❇️ Hope you enjoyed reading!! 📖
# ##### ❇️ follow → @akshay_pachaar
