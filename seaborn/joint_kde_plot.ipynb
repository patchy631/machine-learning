# %% [markdown]
# #### ❇️ Setup

# %%
import seaborn as sns

# %% [markdown]
# #### ❇️ Dataset

# %%
# seaborn provides some builtin datasets. We will use 🐧 penguins dataset today
# to explore more try this 👉 print(sns.get_dataset_names())
penguins = sns.load_dataset('penguins')
penguins.head(2)
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female

# %% [markdown]
# #### ❇️ Joint kde plot

# %%
# Let's say we want a joint kde plot of penguin's bill_depth and bill_length
# the semantic we use here is species.
# We are able to see both univariate and bivariate kde plots 👇 
sns.jointplot(data=penguins, x="bill_length_mm", y="bill_depth_mm", hue="species", kind="kde")

# %% [markdown]
# #### ❇️ Hope you enjoyed reading!! 📖
# #### ❇️ Follow me for more tutorials like this!! 🙌
# #### ❇️ Cheers!! 🍻
