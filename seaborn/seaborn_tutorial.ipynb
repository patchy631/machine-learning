# %% [markdown]
# #### ❇️ Setup

# %%
import seaborn as sns

# %% [markdown]
# #### ❇️ Dataset

# %%
# seaborn provides some builtin datasets. We will use Tips 💵 dataset today
# to explore more try this 👉 print(sns.get_dataset_names())
tips_df = sns.load_dataset('tips')
tips_df.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3

# %% [markdown]
# #### ❇️ Scatter Plot

# %%
# Today we do a scatter plot b/w tip and tip size
# Also, we take into cosideartion two semantics: sex and smoking status
# Check this out 👇 
sns.scatterplot(
    data=tips_df, x="total_bill", y="tip", hue="sex", style="smoker",
    sizes=(20, 200), legend="full" 
)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# #### ❇️ Hope you enjoyed reading!! 📖
# #### ❇️ Follow me for more tutorials like this!! 🙌
# #### ❇️ Cheers!! 🍻

# %% [markdown]
# #### ❇️ Dataset

# %%
# seaborn provides some builtin datasets. We will use Tips 💵 dataset today
# to explore more try this 👉 print(sns.get_dataset_names())
tips_df = sns.load_dataset('tips')
tips_df.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3

# %% [markdown]
# #### ❇️ Violin Plot

# %%
# Today, we see how total_bill varies across diffrent days.
# Note: Violin plots use the kernel density estimation of the data points for these plots.
# Check this out 👇 
sns.violinplot(x="day", y="total_bill", data=tips_df)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# #### ❇️ Lmplot

# %%
# Today, we see how tip varies with on total_bill using a regression plot.
# Notice how behaviour changes for somker and non-smoker.
# Also, we play around with different styling elements.
# Check this out 👇 
g = sns.lmplot(x="total_bill", y="tip", hue="smoker", data=tips_df,
               palette=dict(Yes="m", No="g"))

# %% [markdown]
# #### ❇️ Box Plot

# %%
# Today, we see how total_bill varies across diffrent days in case of men and women.
# Note: the bar in middle of each box represents median and box extends one standard 
# deviation on either side of it.
# Check this out 👇 
sns.boxplot(x='day', y='total_bill', data=tips_df, hue='sex')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# #### ❇️ Joint scatter plot

# %%
# seaborn provides some builtin datasets. We will use 🐧 penguins dataset today
# to explore more try this 👉 print(sns.get_dataset_names())
penguins = sns.load_dataset('penguins')
penguins.head(2)
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female

# %%
# Let's say we want a joint scatter plot of penguin's flipper_length and body_mass
# ideally there must be a direct correlation between the two, check out the plot 👇
sns.jointplot(x='body_mass_g', y='flipper_length_mm', data=penguins, kind='scatter', hue='sex')

# %% [markdown]
# #### ❇️ Pair Plot

# %%
# Plot pairwise relationships in a dataset.
sns.pairplot(penguins, hue='sex')

# %% [markdown]
# #### ❇️ Joint Plot: Hexagonal distribution

# %%
# Let's say we want a joint plot of penguin's flipper_length and body_mass
# ideally there must be a direct correlation between the two, check out the plot 👇
sns.jointplot(x='body_mass_g', y='flipper_length_mm', data=penguins, kind='hex')

# %% [markdown]
# #### ❇️ Joint plot

# %%
# Let's say we want a joint plot of penguin's flipper_length and body_mass
# ideally there must be a direct correlation between the two, check out the plot 👇
sns.jointplot(x='body_mass_g', y='flipper_length_mm', data=penguins, kind='reg')

# %%
# In the next tutorial we will see Hexagon Distribution
# Find link to jupyter notebook 📒 in next tweet.
# Stay tuned!! Cheers!! 🍻

# %% [markdown]
# #### ❇️ Distribution plot

# %%
# Let's say we are interested distribution of body mass of penguins
# you can play around with kind, its can take values such as kde(continous distribution)
sns.displot(penguins['flipper_length_mm'], kind="hist")
