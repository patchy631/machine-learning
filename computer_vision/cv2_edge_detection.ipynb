# %% [markdown]
# #### ❇️ Canny edge detection

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
# Read the original RGB image
img_rgb = cv2.cvtColor(cv2.imread('lena.png') , cv2.COLOR_BGR2RGB)

# Reading as a graycsale image
img_gray = cv2.cvtColor(cv2.imread('lena.png') , cv2.COLOR_BGR2GRAY)

# Blur the image for better edge detection
img_blur = cv2.GaussianBlur(img_gray, (3,3), 0)

# %% [markdown]
# Canny edge detection uses two thresholds threshold1 and threshold2.<br>
# pixel_intensity > threshold2              ----> considered as edge<br>
# pixel_intensity < threshold1              ----> discarded <br>
# threshold1 < pixel_intensity < threshold2 ----> considered as edge if connected to pixels in upper threshold<br>

# %%
# Calculate mean intensity
mean_intensity = np.median(img_blur)

# Set thresholds to be one standard deviation above and below median intensity
threshold1 = int(max(0, (1.0 - 0.33) * mean_intensity))
threshold2 = int(min(255, (1.0 + 0.33) * mean_intensity))

# Apply canny edge detector
img_canny = cv2.Canny(img_blur, threshold1, threshold2)

# %%
# This util is just used for Display purpose
images = [img_rgb, img_gray, img_canny]
image_names = ['img_rgb', 'img_gray', 'img_canny']

num_images = len(images) # Maximum number of images to display
num_cols = 3 # Number of columns in display
num_rows = num_images//num_cols # Number of rows in display
plt.figure(figsize=(20,10*num_cols))
for i in range(num_rows*num_cols):
    
    plt.subplot(num_rows, num_cols, i+1)
    plt.imshow(images[i], cmap='gray')
    plt.title(image_names[i], size=12)
    plt.axis('off')
